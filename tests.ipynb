# %%
from src.groq_client import get_qroq_llm

llm = get_qroq_llm()

response = llm.invoke("Say hello in one sentence")

print(response)
print("----")
print(response.content)
# Out:
# content='Hello!' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 445, 'total_tokens': 508, 'completion_time': 0.1697, 'completion_tokens_details': None, 'prompt_time': 0.058551, 'prompt_tokens_details': None, 'queue_time': 0.305075, 'total_time': 0.228252}, 'model_name': 'groq/compound-mini', 'system_fingerprint': None, 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019ef0a5-1f43-7ef2-8211-c216a15270a9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 445, 'output_tokens': 63, 'total_tokens': 508}
# ----
# Hello!
